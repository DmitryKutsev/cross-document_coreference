# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryKutsev/cross-document_coreference/blob/main/Untitled50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://rucoref.maimbava.net/files/rucoref_29.10.2015.zip
# Out:
# --2021-03-14 16:42:08--  http://rucoref.maimbava.net/files/rucoref_29.10.2015.zip
# Resolving rucoref.maimbava.net (rucoref.maimbava.net)... 116.202.209.138
# Connecting to rucoref.maimbava.net (rucoref.maimbava.net)|116.202.209.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3774313 (3.6M) [application/zip]
# Saving to: ‘rucoref_29.10.2015.zip’
#
# rucoref_29.10.2015. 100%[===================>]   3.60M  3.16MB/s    in 1.1s
#
# 2021-03-14 16:42:09 (3.16 MB/s) - ‘rucoref_29.10.2015.zip’ saved [3774313/3774313]

# %%
# !unzip rucoref_29.10.2015.zip
# Out:
# Archive:  rucoref_29.10.2015.zip
#   inflating: Documents.txt
#   inflating: Groups.txt
#   inflating: groups.xml
#   inflating: Tokens.txt
#    creating: rucoref_texts/fiction/
#   inflating: rucoref_texts/fiction/102_beliajev_nad_bezdnoj.txt
#   inflating: rucoref_texts/fiction/107_dragunsky_volshebnaja_sila_iskusstva.txt
#   inflating: rucoref_texts/fiction/15_paustovsky_zhilcy_starogo_doma.txt
#   inflating: rucoref_texts/fiction/2_astafiev_zhizn_prozhit.txt
#   inflating: rucoref_texts/fiction/30_dojl_sluchaj.txt
#   inflating: rucoref_texts/fiction/34_kassil_solnce_svetit.txt
#   inflating: rucoref_texts/fiction/43_musatov_stozhary.txt
#   inflating: rucoref_texts/fiction/44_nagibin_siren.txt
#   inflating: rucoref_texts/fiction/5_petrushevskaya_v_detstve.txt
#   inflating: rucoref_texts/fiction/53_beliajev_dom_s_prividenijami.txt
#   inflating: rucoref_texts/fiction/67_zamiatin_kolumb.txt
#   inflating: rucoref_texts/fiction/73_ilf_schastlivy_otec.txt
# ...

# %%
ls
# Out:
# Documents.txt  groups.xml       rucoref_29.10.2015.zip  sample_data/
# Groups.txt     parsed_testset/  rucoref_texts/          Tokens.txt

# %%
with open('Groups.txt') as gr:
  groups = gr.read()
  gr.close()

# %%
import pandas as pd

# %%
cor_df = pd.read_csv('Groups.txt', delimiter='\t')

# %%
cor_df
# Out:
#        doc_id  variant  group_id  ...                   attributes  head  hd_shifts
# 0           1        1    407840  ...  ref:def|str:refl|type:coref   NaN        NaN
# 1           1        1    407839  ...  ref:def|str:pron|type:coref   NaN        NaN
# 2           1        1    407842  ...  ref:def|str:noun|type:coref  дачу         78
# 3           1        1    407841  ...  ref:def|str:noun|type:coref  даче        123
# 4           1        1    407843  ...  ref:def|str:pron|type:coref   NaN        NaN
# ...       ...      ...       ...  ...                          ...   ...        ...
# 16552     739        1    475978  ...  ref:def|str:pron|type:coref   NaN        NaN
# 16553     739        1    475979  ...  ref:def|str:poss|type:coref   NaN        NaN
# 16554     739        1    475980  ...  ref:def|str:pron|type:coref   NaN        NaN
# 16555     739        1    475981  ...  ref:def|str:pron|type:coref   NaN        NaN
# ...
