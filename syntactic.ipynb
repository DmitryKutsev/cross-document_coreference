# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryKutsev/cross-document_coreference/blob/main/syntactic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download ru_core_news_sm
# Out:
# ...
# 2021-03-27 14:32:10.492559: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...
#      |████████████████████████████████| 13.7 MB 91 kB/s
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2021-03-27 14:32:20.263794: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...
#      |████████████████████████████████| 17.9 MB 223 kB/s
# ...
#      |████████████████████████████████| 55 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 8.2 MB 5.1 MB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
import spacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
doc = nlp(u'Я принимала антидепрессанты 3 месяца, толку - ноль.\
Бросила пить, хоть в инструкции и стояло, что нельзя бросать резко,\
но я это сделала, так как вообще не видела никакого действия. Последствий никаких, как будто принимала не АД,\
а витамин С... Так что не верю в АД, хотя каждому своё, да и АД разные бвают.')
spacy.displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="13037ddea3e54877bcec132db4c2206a-0" class="displacy" width="9325" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Я</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">принимала</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
# ...

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# Я nsubj принимала VERB []
# принимала ROOT принимала VERB [Я, антидепрессанты, месяца, .]
# антидепрессанты obj принимала VERB []
# 3 nummod:gov месяца NOUN []
# месяца obl принимала VERB [3, толку, -, ноль]
# , punct толку NOUN []
# толку conj месяца NOUN [,]
# - conj месяца NOUN []
# ноль conj месяца NOUN []
# . punct принимала VERB []
# Бросила ROOT Бросила VERB [пить, стояло, .]
# пить xcomp Бросила VERB [инструкции]
# , punct инструкции NOUN []
# хоть advmod инструкции NOUN []
# в case инструкции NOUN []
# инструкции obl пить VERB [,, хоть, в]
# и cc стояло VERB []
# стояло conj Бросила VERB [и, нельзя]
# , punct нельзя ADV []
# что mark нельзя ADV []
# нельзя ccomp стояло VERB [,, что, бросать, сделала]
# бросать csubj нельзя ADV [резко]
# резко advmod бросать VERB []
# , punct сделала VERB []
# но cc сделала VERB []
# я nsubj сделала VERB []
# это obj сделала VERB []
# сделала conj нельзя ADV [,, но, я, это, видела]
# , punct видела VERB []
# так mark видела VERB [как]
# ...

# %%
doc = nlp(u'Стоит ли принимать атаракс? Это хоть и не АД, а транквилизатор, но,\
 читала, что он действует так, что абсолютно все становится пофиг.')
spacy.displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="2d97f72c864648c9984536493f4f5389-0" class="displacy" width="3900" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Стоит</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">ли</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
import string

# %%
for token in doc:
  if token.text not in string.punctuation:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Стоит стоять VERB VERB ROOT Xxxxx True False
# ли ли PART PART advmod xx True False
# принимать принимать VERB VERB csubj xxxx True False
# атаракс атаракс NOUN NOUN obj xxxx True False
# Это это PRON PRON nsubj Xxx True True
# хоть хоть ADV ADV advmod xxxx True False
# и и PART PART advmod x True True
# не не PART PART advmod xx True True
# АД ад PROPN PROPN ROOT XX True False
# а а CCONJ CCONJ cc x True True
# транквилизатор транквилизатор NOUN NOUN conj xxxx True False
# но но CCONJ CCONJ cc xx True True
# читала читать VERB VERB conj xxxx True False
# что что SCONJ SCONJ mark xxx True True
# он он PRON PRON nsubj xx True True
# действует действовать VERB VERB ccomp xxxx True False
# так так ADV ADV advmod xxx True True
# что что SCONJ SCONJ mark xxx True True
# абсолютно абсолютно ADV ADV advmod xxxx True False
# все все PRON PRON nsubj xxx True True
# становится становиться VERB VERB advcl xxxx True False
# пофиг пофиг NOUN NOUN nsubj xxxx True False

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# Стоит ROOT Стоит VERB [ли, принимать, ?]
# ли advmod Стоит VERB []
# принимать csubj Стоит VERB [атаракс]
# атаракс obj принимать VERB []
# ? punct Стоит VERB []
# Это nsubj АД PROPN []
# хоть advmod АД PROPN []
# и advmod АД PROPN []
# не advmod АД PROPN []
# АД ROOT АД PROPN [Это, хоть, и, не, транквилизатор, читала, .]
# , punct транквилизатор NOUN []
# а cc транквилизатор NOUN []
# транквилизатор conj АД PROPN [,, а]
# , punct читала VERB []
# но cc читала VERB []
# , punct читала VERB []
# читала conj АД PROPN [,, но, ,, действует]
# , punct действует VERB []
# что mark действует VERB []
# он nsubj действует VERB []
# действует ccomp читала VERB [,, что, он, так]
# так advmod действует VERB [становится]
# , punct становится VERB []
# что mark становится VERB []
# абсолютно advmod все PRON []
# все nsubj становится VERB [абсолютно]
# становится advcl так ADV [,, что, все, пофиг]
# пофиг nsubj становится VERB []
# . punct АД PROPN []
